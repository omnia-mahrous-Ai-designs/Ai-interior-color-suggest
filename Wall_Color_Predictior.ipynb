# %% [markdown]
# <a href="https://colab.research.google.com/github/omnia-mahrous-Ai-designs/Ai-interior-color-suggest/blob/main/Wall_Color_Predictior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to the AI Interior color suggest project!")
# Out:
# welcome to the AI Interior color suggest project!

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data = {"room_type":["bedroom", "livingroom", "kitchen", "office","bedroom"],"area": [12, 25, 10, 18, 15]
,"light_level": [2,  3, 1, 2, 1],"wall_color_code":[1, 2, 1, 3, 1]}

# %%
df = pd.DataFrame(data)
df
# Out:
#     room_type  area  light_level  wall_color_code
# 0     bedroom    12            2                1
# 1  livingroom    25            3                2
# 2     kitchen    10            1                1
# 3      office    18            2                3
# 4     bedroom    15            1                1

# %%
#from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["room_type_encoded"] = le.fit_transform(df["room_type"])
df
# Out:
#     room_type  area  light_level  wall_color_code  room_type_encoded
# 0     bedroom    12            2                1                  0
# 1  livingroom    25            3                2                  2
# 2     kitchen    10            1                1                  1
# 3      office    18            2                3                  3
# 4     bedroom    15            1                1                  0

# %%
x = df[["room_type_encoded", "area", "light_level"]]
y = df["wall_color_code"]

# %%
#from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
new_room = [[0, 14, 2]]
predicted_color = model.predict(new_room)
print("suggested wall color code:",predicted_color[0])
# Out:
# suggested wall color code: 0.8527988942639949
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
new_data = pd.DataFrame({'room_type_encoded':[0],'area':[14],'light_level':[2]})
Prediction = model.predict(new_data)
print("suggested wall color code:",Prediction[0])
# Out:
# suggested wall color code: 0.8527988942639949

# %%
color_map = {1: "Blue",
             2: "Beige",
             3: "Green"
}
predicted_color = color_map.get(round(predicted_color[0]), "Unkown")
print("predicted wall color:",predicted_color)
# Out:
# predicted wall color: Blue

# %%
test_room = pd.DataFrame({'room_type_encoded': [2], 'area': [8],'light_level' :[3]})
prediction = model.predict(test_room)
print("predicted wall color code:",round(prediction[0]))
print("predicted wall color:",color_map.get(round(prediction[0]), "Unknown"))
# Out:
# predicted wall color code: 2
# predicted wall color: Beige
